# %%
import matplotlib.pyplot as plt
import numpy as np
# filename='fig_'

# import os
# image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
# type(image_path)

# %% [markdown]
# D2Q9

# %%
import matplotlib.pyplot as plt
import numpy as np
filename='fig_'

import os
image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
type(image_path)

# data=np.loadtxt(fname='Q21_DRTT.txt',delimiter = ',',skiprows=1)





d1=np.loadtxt(fname='./datas/maxwell_construction.csv',delimiter = ',',skiprows=1)
d2=np.loadtxt(fname='./datas/maxwell_construction_mathematica.csv',delimiter = ',',skiprows=0)
d3=np.loadtxt(fname='./datas/maxwell_construction_praveen.csv',delimiter = ',',skiprows=0)
d4=np.loadtxt(fname='./datas/with_MU.txt',delimiter = ',',skiprows=1)
d5=np.loadtxt(fname='./datas/with_central_derivative.txt',delimiter = ',',skiprows=1)
d6=np.loadtxt(fname='./datas/with_surface_term.txt',delimiter = ',',skiprows=1) #it is needed
d7=np.loadtxt(fname='./datas/from_second_order.txt',delimiter = ',',skiprows=1)





fig = plt.figure(figsize=(6,4))
ax1 = fig.add_axes([0,0,1,1])

# ax1.plot(rho,Temp,'.', label = 'Analytical match from Mathematica')
ax1.plot(d3[:,0],d3[:,1],'-',label = 'maxwell_construction')
# ax1.plot(d5[:,1],d5[:,0],'<',label = 'central difference')
# ax1.plot(d6[:,1],d6[:,0],'>',label = '2nd order')
# ax1.plot(d7[:,1],d7[:,0],'^',label = 'fourth order')

# ax1.plot(d4[:,1],d4[:,0],'<',label = 'chemical potential formulation')
# ax1.plot(d8[:,1],d8[:,0],'<',label = 'mixed order')
ax1.plot(d9[:,1],d9[:,0],'<',label = 'mixed order')

# ax1.plot(y1,x,'>',label = "pressure_formulation")



plt.title("maxwell _construction")


ax1.set_xlabel(r'$\rho / \rho_{c}$')
ax1.set_ylabel(r'$T / T_{c}$')


# 

ax1.grid(alpha=0.5,lw=0.5,ls='--',color='tab:gray')
ax1.legend()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /home/ganesh/Desktop/Codes/multiphase/D1Q_VW/testnotebook.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/home/ganesh/Desktop/Codes/multiphase/D1Q_VW/testnotebook.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a> d2=np.loadtxt(fname='./datas/maxwell_construction_mathematica.csv',delimiter = ',',skiprows=0)
#      <a href='vscode-notebook-cell:/home/ganesh/Desktop/Codes/multiphase/D1Q_VW/testnotebook.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> d3=np.loadtxt(fname='./datas/maxwell_construction_praveen.csv',delimiter = ',',skiprows=0)
# ---> <a href='vscode-notebook-cell:/home/ganesh/Desktop/Codes/multiphase/D1Q_VW/testnotebook.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> d4=np.loadtxt(fname='./datas/with_MU.txt',delimiter = ',',skiprows=1)
#      <a href='vscode-notebook-cell:/home/ganesh/Desktop/Codes/multiphase/D1Q_VW/testnotebook.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> d5=np.loadtxt(fname='./datas/with_central_derivative.txt',delimiter = ',',skiprows=1)
#      <a href='vscode-notebook-cell:/home/ganesh/Desktop/Codes/multiphase/D1Q_VW/testnotebook.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a> d6=np.loadtxt(fname='./datas/with_surface_term.txt',delimiter = ',',skiprows=1) #it is needed
#
# File /usr/lib/python3/dist-packages/numpy/lib/npyio.py:1067, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065     fname = os_fspath(fname)
#    1066 if _is_string_like(fname):
# -> 1067     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068     fencoding = getattr(fh, 'encoding', 'latin1')
#    1069     fh = iter(fh)
#
# File /usr/lib/python3/dist-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /usr/lib/python3/dist-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise IOError("%s not found." % path)
#
# OSError: ./datas/with_MU.txt not found.

# %%
import matplotlib.pyplot as plt
import numpy as np
filename='fig_'

import os
image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
type(image_path)

# data=np.loadtxt(fname='Q21_DRTT.txt',delimiter = ',',skiprows=1)





d1=np.loadtxt(fname='./datas/maxwell_construction.csv',delimiter = ',',skiprows=1)
d2=np.loadtxt(fname='./datas/maxwell_construction_mathematica.csv',delimiter = ',',skiprows=0)
d3=np.loadtxt(fname='./datas/maxwell_construction_praveen.csv',delimiter = ',',skiprows=0)
d4=np.loadtxt(fname='./datas/chemical_potential.txt',delimiter = ',',skiprows=1)
d5=np.loadtxt(fname='./datas/4th.txt',delimiter = ',',skiprows=1)
d6=np.loadtxt(fname='./datas/2nd.txt',delimiter = ',',skiprows=1)
d7=np.loadtxt(fname='./datas/2nd_new_product_rule.txt',delimiter = ',',skiprows=1)





fig = plt.figure(figsize=(6,4))
ax1 = fig.add_axes([0,0,1,1])

# ax1.plot(rho,Temp,'.', label = 'Analytical match from Mathematica')
ax1.plot(d3[:,0],d3[:,1],'-',label = 'maxwell_construction')
ax1.plot(d4[:,1],d4[:,0],'>',label = 'chemical_potential')
ax1.plot(d5[:,1],d5[:,0],'<',label = '4th')
# ax1.plot(d6[:,1],d6[:,0],'>',label = '2nd')
ax1.plot(d7[:,1],d7[:,0],'^',label = '2nd_order')

# ax1.plot(d5[:,1],d5[:,0],'<',label = 'central difference')
# ax1.plot(d6[:,1],d6[:,0],'>',label = '2nd order')


# ax1.plot(y1,x,'>',label = "pressure_formulation")

plt.title("maxwell _construction")


ax1.set_xlabel(r'$\rho / \rho_{c}$')
ax1.set_ylabel(r'$T / T_{c}$')


# 

ax1.grid(alpha=0.5,lw=0.5,ls='--',color='tab:gray')
ax1.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
filename='fig_'

import os
image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
type(image_path)

# data=np.loadtxt(fname='Q21_DRTT.txt',delimiter = ',',skiprows=1)





d1=np.loadtxt(fname='./outputs/rho49500.dat',delimiter =',',skiprows=1)
# d1=np.loadtxt(fname='./outputs/rho990000.dat',delimiter =',',skiprows=1)





fig = plt.figure(figsize=(6,4))
ax1 = fig.add_axes([0,0,1,1])

ax1.plot(d1[:,0],d1[:,1],'-',label = 'maxwell_construction')




plt.title("maxwell _construction")


ax1.set_xlabel(r'x')
ax1.set_ylabel(r'$\rho / \rho_{c}$')


# 

ax1.grid(alpha=0.5,lw=0.5,ls='--',color='tab:gray')
ax1.legend()
