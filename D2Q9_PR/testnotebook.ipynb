# %%
import matplotlib.pyplot as plt
import numpy as np
# filename='fig_'

# import os
# image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
# type(image_path)

# %% [markdown]
# D2Q9

# %%
import matplotlib.pyplot as plt
import numpy as np
filename='fig_'

import os
image_path = os.path.abspath(filename) # Figures out the absolute path for you in case your working directory moves around.
type(image_path)

# data=np.loadtxt(fname='Q21_DRTT.txt',delimiter = ',',skiprows=1)





d1=np.loadtxt(fname='./datas/maxwell_construction.csv',delimiter = ',',skiprows=1)
d2=np.loadtxt(fname='./datas/carnahan_starling_maxwell_construction.csv',delimiter = ',',skiprows=0)
d3=np.loadtxt(fname='./datas/chemical_potential.txt',delimiter = ',',skiprows=1)
# d4=np.loadtxt(fname='./datas/2nd_order.txt',delimiter = ',',skiprows=1)
# d5=np.loadtxt(fname='./datas/4th_order.txt',delimiter = ',',skiprows=1)

fig = plt.figure(figsize=(6,4))
ax1 = fig.add_axes([0,0,1,1])

# ax1.plot(rho,Temp,'.', label = 'Analytical match from Mathematica')
ax1.plot(d2[:,0],d2[:,1],'--',label = 'maxwell_construction')
ax1.plot(d3[:,1],d3[:,0],'>',label = 'chemical potential formulation')
# ax1.plot(d4[:,1],d4[:,0],'<',label = '2nd_order')
# ax1.plot(d5[:,1],d5[:,0],'<',label = '4th')





plt.title("maxwell _construction")


ax1.set_xlabel(r'$\rho / \rho_{c}$')
ax1.set_ylabel(r'$T / T_{c}$')


# 

ax1.grid(alpha=0.5,lw=0.5,ls='--',color='tab:gray')
ax1.legend()
